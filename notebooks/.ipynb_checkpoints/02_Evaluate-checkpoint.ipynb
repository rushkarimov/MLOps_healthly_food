# %%
import os

import numpy as np
import pandas as pd

import joblib

from typing import Dict

import yaml
import json

import warnings
warnings.filterwarnings("ignore")

# %%
config_path = '../config/params.yml'
config = yaml.load(open(config_path), Loader=yaml.FullLoader)

preproc = config['preprocessing']
training = config['train']
evaluate = config['evaluate']


# check columns with train
column_sequence_path = preproc['unique_values_path']
with open(column_sequence_path) as json_file:
    column_sequence = json.load(json_file)

# %% [markdown]
# # Import

# %%
data_test = pd.read_csv(evaluate['predict_path'])
data_test[:4]
# Out:
#        id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110   Male   25                1           11                   1
# 1  381111   Male   40                1           28                   0
# 2  381112   Male   47                1           28                   0
# 3  381113   Male   24                1           27                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No         35786.0                   152       53
# 1    1-2 Year            Yes         33762.0                     7      111
# 2    1-2 Year            Yes         40050.0                   124      199
# 3    < 1 Year            Yes         37356.0                   152      187

# %% [markdown]
# # Preprocessing

# %%
def replace_values(data: pd.DataFrame, map_change_columns: dict) -> pd.DataFrame:
    """
    Замена значений в датасете
    :param data: датасет
    :param map_change_columns: словарь с признаками и значениями
    :return: датасет
    """
    return data.replace(map_change_columns)


def transform_types(data: pd.DataFrame, change_type_columns: dict) -> pd.DataFrame:
    """
    Преобразование признаков в заданный тип данных
    :param data: датасет
    :param change_type_columns: словарь с признаками и типами данных
    :return:
    """
    return data.astype(change_type_columns, errors="raise")


def get_bins(
    data: (int, float), first_val: (int, float), second_val: (int, float)
) -> str:
    """
    Генерация бинов для разных признаков
    :param data: датасет
    :param first_val: первый порог значения для разбиения на бины
    :param second_val: второй порог значения для разбиения на бины
    :return: датасет
    """
    assert isinstance(data, (int, float)), "Проблема с типом данных в признаке"
    result = (
        "small"
        if data <= first_val
        else "medium"
        if first_val < data <= second_val
        else "large"
    )
    return result


def check_columns_evaluate(data: pd.DataFrame, unique_values_path: str) -> pd.DataFrame:
    """
    Проверка на наличие признаков из train и упорядочивание признаков согласно train
    :param data: датасет test
    :param unique_values_path: путь до списока с признаками train для сравнения
    :return: датасет test
    """
    with open(unique_values_path) as json_file:
        unique_values = json.load(json_file)

    column_sequence = unique_values.keys()

    assert set(column_sequence) == set(data.columns), "Разные признаки"
    return data[column_sequence]

# %%
def pipeline_preprocess(data: pd.DataFrame, flg_evaluate: bool = True, **kwargs):
    """
    Пайплайн по предобработке данных
    :param data: датасет
    :param flg_evaluate: флаг для evaluate
    :return: датасет
    """
    # drop columns
    data = data.drop(kwargs["drop_columns"], axis=1, errors="ignore")
    # проверка dataset на совпадение с признаками из train
    # либо сохранение уникальных данных с признаками из train
    if flg_evaluate:
        data = check_columns_evaluate(
            data=data, unique_values_path=kwargs["unique_values_path"]
        )
    else:
        save_unique_train_data(
            data=data,
            drop_columns=kwargs["drop_columns"],
            target_column=kwargs["target_column"],
            unique_values_path=kwargs["unique_values_path"],
        )

    # replace values
    data = replace_values(data=data, map_change_columns=kwargs["map_change_columns"])

    # transform types
    data = transform_types(data=data, change_type_columns=kwargs["change_type_columns"])

    assert isinstance(
        kwargs["map_bins_columns"], dict
    ), "Подайте тип данных для бинаризации в формате dict"
    # bins
    for key in kwargs["map_bins_columns"].keys():
        data[f"{key}_bins"] = data[key].apply(
            lambda x: get_bins(
                x,
                first_val=kwargs["map_bins_columns"][key][0],
                second_val=kwargs["map_bins_columns"][key][1],
            )
        )

    # change category types
    dict_category = {key: "category" for key in data.select_dtypes(["object"]).columns}
    data = transform_types(data=data, change_type_columns=dict_category)
    return data

# %%
dict(data_test.iloc[0])
# Out:
# {'id': 381110,
#  'Gender': 'Male',
#  'Age': 25,
#  'Driving_License': 1,
#  'Region_Code': 11,
#  'Previously_Insured': 1,
#  'Vehicle_Age': '< 1 Year',
#  'Vehicle_Damage': 'No',
#  'Annual_Premium': 35786.0,
#  'Policy_Sales_Channel': 152,
#  'Vintage': 53}

# %%
data_test.iloc[:,:5]
# Out:
#             id  Gender  Age  Driving_License  Region_Code
# 0       381110    Male   25                1           11
# 1       381111    Male   40                1           28
# 2       381112    Male   47                1           28
# 3       381113    Male   24                1           27
# 4       381114    Male   27                1           28
# ...        ...     ...  ...              ...          ...
# 127032  508142  Female   26                1           37
# 127033  508143  Female   38                1           28
# 127034  508144    Male   21                1           46
# 127035  508145    Male   71                1           28
# 127036  508146    Male   41                1           29
#
# [127037 rows x 5 columns]

# %%
data_proc_test = pipeline_preprocess(data=data_test.iloc[:,:5], **preproc)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-403729955508> in <module>
# ----> 1 data_proc_test = pipeline_preprocess(data=data_test.iloc[:,:5], **preproc)
#
# <ipython-input-5-01a4d38bd534> in pipeline_preprocess(data, flg_evaluate, **kwargs)
#      11     # либо сохранение уникальных данных с признаками из train
#      12     if flg_evaluate:
# ---> 13         data = check_columns_evaluate(
#      14             data=data, unique_values_path=kwargs["unique_values_path"]
#      15         )
#
# <ipython-input-4-8b498d311335> in check_columns_evaluate(data, unique_values_path)
#      52     column_sequence = unique_values.keys()
#      53
# ---> 54     assert set(column_sequence) == set(data.columns), "Разные признаки"
#      55     return data[column_sequence]
#
# AssertionError: Разные признаки

# %%
data_proc_test = pipeline_preprocess(data=data_test, **preproc)

# %%
data_proc_test[:4]
# Out:
#   Gender  Age  Driving_License Region_Code  Previously_Insured  Vehicle_Age  \
# 0   Male   25                1          11                   1  less_1_year
# 1   Male   40                1          28                   0     1_2_year
# 2   Male   47                1          28                   0     1_2_year
# 3   Male   24                1          27                   1  less_1_year
#
#    Vehicle_Damage  Annual_Premium Policy_Sales_Channel  Vintage Age_bins  \
# 0               0         35786.0                  152       53    small
# 1               1         33762.0                    7      111   medium
# 2               1         40050.0                  124      199   medium
# 3               1         37356.0                  152      187    small
#
#   Annual_Premium_bins Vintage_bins
# 0              medium       medium
# 1              medium       medium
# 2               large        large
# 3              medium        large

# %%
data_proc_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127037 entries, 0 to 127036
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                127037 non-null  category
#  1   Age                   127037 non-null  int64
#  2   Driving_License       127037 non-null  int64
#  3   Region_Code           127037 non-null  category
#  4   Previously_Insured    127037 non-null  int64
#  5   Vehicle_Age           127037 non-null  category
#  6   Vehicle_Damage        127037 non-null  int64
#  7   Annual_Premium        127037 non-null  float64
#  8   Policy_Sales_Channel  127037 non-null  category
#  9   Vintage               127037 non-null  int64
#  10  Age_bins              127037 non-null  category
#  11  Annual_Premium_bins   127037 non-null  category
#  12  Vintage_bins          127037 non-null  category
# dtypes: category(7), float64(1), int64(5)
# memory usage: 6.8 MB

# %% [markdown]
# Если используете модель, где необходимо сделать One-Hot кодирование, то у вас могут различаться признаки. В этом случае вам необходимо добавить недостающие бинаризованные признаки заполненные 'None'/0 (то есть как будто они пустые), а уже далее проверить на соответствие признаки. Но и признаки для train нужно сохранять тогда до и после бинаризации

# %% [markdown]
# # Evaluate

# %%
model = joblib.load(training['model_path'])
data_proc_test['predict'] = model.predict(data_proc_test)

# %%
data_proc_test
# Out:
#         Gender  Age  Driving_License Region_Code  Previously_Insured  \
# 0         Male   25                1          11                   1
# 1         Male   40                1          28                   0
# 2         Male   47                1          28                   0
# 3         Male   24                1          27                   1
# 4         Male   27                1          28                   1
# ...        ...  ...              ...         ...                 ...
# 127032  Female   26                1          37                   1
# 127033  Female   38                1          28                   0
# 127034    Male   21                1          46                   1
# 127035    Male   71                1          28                   1
# 127036    Male   41                1          29                   1
#
#         Vehicle_Age  Vehicle_Damage  Annual_Premium Policy_Sales_Channel  \
# 0       less_1_year               0         35786.0                  152
# 1          1_2_year               1         33762.0                    7
# 2          1_2_year               1         40050.0                  124
# 3       less_1_year               1         37356.0                  152
# 4       less_1_year               0         59097.0                  152
# ...             ...             ...             ...                  ...
# 127032  less_1_year               0         30867.0                  152
# 127033     1_2_year               1         28700.0                  122
# 127034  less_1_year               0         29802.0                  152
# 127035     1_2_year               0         62875.0                   26
# 127036     1_2_year               0         27927.0                  124
#
#         Vintage Age_bins Annual_Premium_bins Vintage_bins  predict
# 0            53    small              medium       medium        0
# 1           111   medium              medium       medium        1
# 2           199   medium               large        large        1
# 3           187    small              medium        large        0
# 4           297    small               large        large        0
# ...         ...      ...                 ...          ...      ...
# 127032       56    small              medium       medium        0
# 127033      165   medium              medium       medium        1
# 127034       74    small              medium       medium        0
# 127035      265    large               large        large        0
# 127036      231   medium              medium        large        0
#
# [127037 rows x 14 columns]
